# %% [markdown]
# ### Dataset GRÃ-BRETANHA

# %%
#Importando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import datetime
from collections import Counter
from sklearn.model_selection import cross_val_score

import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)

# %%
df_GB = pd.read_csv('desktop/GBvideos.csv', delimiter=',')
df_GB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38916 entries, 0 to 38915
# Data columns (total 16 columns):
# video_id                  38916 non-null object
# trending_date             38916 non-null object
# title                     38916 non-null object
# channel_title             38916 non-null object
# category_id               38916 non-null int64
# publish_time              38916 non-null object
# tags                      38916 non-null object
# views                     38916 non-null int64
# likes                     38916 non-null int64
# dislikes                  38916 non-null int64
# comment_count             38916 non-null int64
# thumbnail_link            38916 non-null object
# comments_disabled         38916 non-null bool
# ratings_disabled          38916 non-null bool
# video_error_or_removed    38916 non-null bool
# description               38304 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.0+ MB

# %%
df_GB.head().T
# Out:
#                                                                         0  \
# video_id                                                      Jw1Y-zhQURU
# trending_date                                                    17.14.11
# title                       John Lewis Christmas Ad 2017 - #MozTheMonster
# channel_title                                                  John Lewis
# category_id                                                            26
# publish_time                                     2017-11-10T07:38:29.000Z
# tags                    christmas|"john lewis christmas"|"john lewis"|...
# views                                                             7224515
# likes                                                               55681
# dislikes                                                            10247
# comment_count                                                        9479
# thumbnail_link             https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Click here to continue the story and make your...
#
#                                                                         1  \
# video_id                                                      3s1rvMFUweQ
# trending_date                                                    17.14.11
# title                           Taylor Swift: …Ready for It? (Live) - SNL
# channel_title                                         Saturday Night Live
# category_id                                                            24
# publish_time                                     2017-11-12T06:24:44.000Z
# tags                    SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...
# views                                                             1053632
# likes                                                               25561
# dislikes                                                             2294
# comment_count                                                        2757
# thumbnail_link             https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Musical guest Taylor Swift performs …Ready for...
#
#                                                                         2  \
# video_id                                                      n1WpP7iowLc
# trending_date                                                    17.14.11
# title                          Eminem - Walk On Water (Audio) ft. Beyoncé
# channel_title                                                  EminemVEVO
# category_id                                                            10
# publish_time                                     2017-11-10T17:00:03.000Z
# tags                    Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# views                                                            17158579
# likes                                                              787420
# dislikes                                                            43420
# comment_count                                                      125882
# thumbnail_link             https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Eminem's new track Walk on Water ft. Beyoncé i...
#
#                                                                         3  \
# video_id                                                      PUTEiSjKwJU
# trending_date                                                    17.14.11
# title                   Goals from Salford City vs Class of 92 and Fri...
# channel_title                                  Salford City Football Club
# category_id                                                            17
# publish_time                                     2017-11-13T02:30:38.000Z
# tags                    Salford City FC|"Salford City"|"Salford"|"Clas...
# views                                                               27833
# likes                                                                 193
# dislikes                                                               12
# comment_count                                                          37
# thumbnail_link             https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Salford drew 4-4 against the Class of 92 and F...
#
#                                                                         4
# video_id                                                      rHwDegptbI4
# trending_date                                                    17.14.11
# title                   Dashcam captures truck's near miss with child ...
# channel_title                                            Cute Girl Videos
# category_id                                                            25
# publish_time                                     2017-11-13T01:45:13.000Z
# tags                                                               [none]
# views                                                                9815
# likes                                                                  30
# dislikes                                                                2
# comment_count                                                          30
# thumbnail_link             https://i.ytimg.com/vi/rHwDegptbI4/default.jpg
# comments_disabled                                                   False
# ratings_disabled                                                    False
# video_error_or_removed                                              False
# description             Dashcam captures truck's near miss with child ...

# %% [markdown]
# ### Tratamento do DataFrame

# %%
#Fazendo uma cópia do Dataframe
df_GB = df_GB.copy()

# %%
df_GB.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  38916.000000  3.891600e+04  3.891600e+04  3.891600e+04   3.891600e+04
# mean      16.827937  5.911944e+06  1.345196e+05  7.612560e+03   1.308835e+04
# std        7.752728  1.900121e+07  3.499893e+05  5.095683e+04   5.066740e+04
# min        1.000000  8.510000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       10.000000  2.515272e+05  5.897000e+03  2.000000e+02   6.790000e+02
# 50%       20.000000  9.818890e+05  2.518250e+04  8.210000e+02   2.478000e+03
# 75%       24.000000  3.683628e+06  1.140892e+05  3.357500e+03   9.241500e+03
# max       43.000000  4.245389e+08  5.613827e+06  1.944971e+06   1.626501e+06

# %%
#Importando o json para ver a category_id
#root:{} 3 items
#kind:youtube#videoCategoryListResponse
#etag:"m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2qTj13hkQZk"
#items:[] 31 items

import json

with open('desktop/GB_category_id.json', 'r') as f:
  categ_gb = json.load(f)

for k in categ_gb['items']:
  print(k['id'], k['snippet']['title'])
# Out:
# 1 Film & Animation
# 2 Autos & Vehicles
# 10 Music
# 15 Pets & Animals
# 17 Sports
# 18 Short Movies
# 19 Travel & Events
# 20 Gaming
# 21 Videoblogging
# 22 People & Blogs
# 23 Comedy
# 24 Entertainment
# 25 News & Politics
# 26 Howto & Style
# 27 Education
# 28 Science & Technology
# 30 Movies
# 31 Anime/Animation
# 32 Action/Adventure
# 33 Classics
# 34 Comedy
# 35 Documentary
# 36 Drama
# 37 Family
# 38 Foreign
# 39 Horror
# 40 Sci-Fi/Fantasy
# 41 Thriller
# 42 Shorts
# 43 Shows
# 44 Trailers

# %%
#Analisando a quantidade de categorias 

import json

# open json file with category names
with open('desktop/GB_category_id.json', 'r') as f:
  categ_us = json.load(f)

categ_dic = {}

for k in categ_us['items']:
  categ_dic[k['id']]= k['snippet']['title']

#print(categ_dic)

# Creating new column with category names
temp = df_GB.category_id.copy()
temp = temp.astype('str')
df_GB['category_name'] = temp.map(categ_dic)

#print(df.loc[:10, ['category_id', 'category_name']])

# %%
df_GB2 = df_GB.copy()
df_GB2.drop_duplicates('video_id', inplace=True)
sns.countplot(y='category_name', data=df_GB2, order=df_GB2.category_name.value_counts().index )
plt.title('Category popularity among top 200')
plt.ylabel('Category')
# Out:
# Text(0, 0.5, 'Category')

# %% [markdown]
# ### Outliers

# %%
#Função para detectar os outliers do novo DataFrame

def detect_outliers(df_GB2,n,features):
    outlier_indices = []
    
    for col in features:

        Q1 = np.percentile(df_GB2[col], 25)
        Q3 = np.percentile(df_GB2[col],75)
        IQR = Q3 - Q1

        outlier_step = 1.5 * IQR
        outlier_list_col = df_GB2[(df_GB2[col] < Q1 - outlier_step) | (df_GB2[col] > Q3 + outlier_step )].index
        outlier_indices.extend(outlier_list_col)

    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers

# %%
Outliers_to_drop = detect_outliers(df_GB2,1,['views', 'likes', 'dislikes', 'comment_count'])

# %%
df_GB2.loc[Outliers_to_drop]
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 2      n1WpP7iowLc      17.14.11
#
# 38416  샤이니|"SHINee"|"태민"|"민호"|"온유"|"키"|"종현"|"TAEMIN"|...   1412340   257843
# 43     Columbia|"Hip Hop"|"Remy Ma feat. Lil' Kim"|"W...   1231518    32648
# 94     The Late Show|"Stephen Colbert"|"Colbert"|"Lat...   1189325    21859
# 143    ijustine|"iphone x"|"iphone x review"|"iphone ...   1703026    51996
# 621    Columbia|"Hip Hop"|"Remy Ma feat. Lil' Kim"|"W...    804363    39817
# 1200   CUPHEAD|"MUGMAN"|"DON'T DEAL WITH THE DEVIL"|"...   1260669    79092
# 6199   thedc|"dc"|"washington dc"|"washington"|"the d...    649781     5505
# 6798   angryjoe|"angryjoeshow"|"angry rant"|"rant"|"s...    662420    33365
# 7795   R&B|"SZA"|"The Weekend"|"Top Dawg Entertainmen...   1292926    77746
# 8593   regenerate|"regeneration"|"thirteenth doctor"|...    747653    21209
# 10195  TMZ2016FS11221|"TMZ"|"Hollywood"|"Celebrity"|"...   1300016    35261
# 10400  danielle bregoli|"cash me ousside"|"cash me ou...    822906    75798
# 11596  jimmy|"jimmy kimmel"|"jimmy kimmel live"|"late...   1710666    18761
# 12412  red nose day|"gucci gang"|"gucci gang stream"|...   1828286    56093
# 13397  ugandan knuckles memes|"ugandan knuckles"|"uga...   1874710    54224
# 15405  I HATE EVERYTHING|"I hate"|"everything"|"hate ...    702474    36138
# 16000  Iggy Azalea|"Iggy"|"Azalea"|"Savior"|"Quavo"|"...   1258116    75257
# 16190  NFL|"Football"|"offense"|"defense"|"afc"|"nfc"...   2027569    50251
# 18583  jimmy|"jimmy kimmel"|"jimmy kimmel live"|"late...   1797096    52576
# 18980  latest News|"Happening Now"|"CNN"|"parkland"|"...   1032769    33225
# 26527  screen junkies news|"screenjunkies"|"screenjun...   2242244    66380
# 26536  danielle bregoli|"cash me ousside"|"cash me ou...   1309980    82211
# 30797  Fox News Channel|"FNC"|"Fox News"|"Fox"|"News"...   1221360     6952
# 33809  the breakfast club|"power1051"|"celebrity news...   1226764    19290
# 35271  call of duty|"cod"|"activision"|"Zombies"|"Bla...   1248113    68082
# 35435                                             [none]   1631193    28071
# 35921  latest News|"Happening Now"|"CNN"|"US"|"Newsro...   2232908     7101
# 38588  film|"gdnpfpculturefilm"|"Robert de Niro"|"Don...   1805611    20288
#
#        dislikes  comment_count  \
# 0         10247           9479
# 2         43420         125882
# 6         21082          85067
# 9         15015          11473
# 17         4083          12254
# 18         3394          20086
# 21         1502          10706
# 22         3167          13279
# 28         2573          12248
# 35        10294           5903
# 53        16139          59482
# 59         2766           7176
# 84         9704          17556
# 93        33231          34911
# 97         4826          23030
# 101        1684          10318
# 104        1768          31872
# 119        8972              0
# 131       13504          11789
# 139       16758          11083
# 140        3422          25986
# 147       20257          50164
# 152        8251           6312
# 156        8489          11579
# 157         856           4299
# 166        3372          28700
# 167       12903          10619
# 168        2199           8395
# 177        8120          19807
# 198        2322           9793
# ...         ...            ...
# 36395      1196          20647
# 37565      2664          14693
# 38416       661          17079
# 43         6221           9288
# 94         7016          11869
# 143        8415           9422
# 621        6304          10586
# 1200       2966          10670
# 6199     140077          16730
# 6798       7442          17215
# 7795       6946          11701
# 8593       2968           9342
# 10195      8262          12362
# 10400      3719          10464
# 11596      4545          11071
# 12412      6799          14090
# 13397      4897          14099
# 15405      3371          11793
# 16000      6685           9272
# 16190     15239          14413
# 18583      9983          19730
# 18980      6499          30637
# 26527      4752          15201
# 26536      4608          10434
# 30797      4353          12770
# 33809      6581          19661
# 35271      2864           9697
# 35435     13497          10610
# 35921      6865          24228
# 38588     10426          16351
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg              False
# 2      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
#
# 59     This episode is brought to you by T-Mobile. No...      Film & Animation
# 84     The brand new single from Liam Payne. Listen t...                 Music
# 93       Upgrade to Galaxy.\nLearn more: smsng.us/Switch         Entertainment
# 97     EXID가 네 번째 미니앨범 [Full Moon]으로 돌아왔다.\n\n지난 앨범 [...         Entertainment
# 101    ★iTunes : https://goo.gl/T52uzW\n    Spotify :...                 Music
# 104    iTunes Download ▶ https://itunes.apple.com/alb...                 Music
# 119    The #1 hit-single by Post Malone. rockstar fea...                 Music
# 131    HI SISTERS! Apple just dropped the brand new i...         Entertainment
# 139    Guest Host and Kardashian super fan Jennifer L...                Comedy
# 140    Tensions between the Alliance and Horde have e...                Gaming
# 147    Get Taylor Swift’s new album, reputation, incl...                 Music
# 152    WATCH MY PREVIOUS VIDEO ▶ https://youtu.be/txn...                Comedy
# 156    Listen to MotorSport (feat. Nicki Minaj & Card...                 Music
# 157    Stranger Things stars Finn Wolfhard, Gaten Mat...                Comedy
# 166    BRAIN CANDY LIVE http://www.braincandylive.com...         Entertainment
# 167    Lemon performed by N.E.R.D and Rihanna is out ...                 Music
# 168    Darkness rises… and light to meet it. See Star...         Entertainment
# 177    Get ‘Wolves,' out now: http://smarturl.it/Wolv...                 Music
# 198    Wendy Williams overheated in her Halloween cos...         Entertainment
# ...                                                  ...                   ...
# 36395  ‘Humility' feat. George Benson is taken from t...                 Music
# 37565  “Bloom” available now: https://TroyeSivan.lnk....                 Music
# 38416  SHINee's the 6th album 'The Story of Light’ EP...                 Music
# 43     Remy Ma - Wake Me Up featuring Lil' Kim (Offic...                 Music
# 94     Stephen expresses his feelings on the most use...         Entertainment
# 143    Meet the new iPhone X. As if I haven't posted ...  Science & Technology
# 621    Remy Ma - Wake Me Up featuring Lil' Kim (Offic...                 Music
# 1200   Cuphead learns the hard way that sometimes ya ...      Film & Animation
# 6199   Ajit Pai has been at the heart of the net neut...        People & Blogs
# 6798   While I did enjoy The Last Jedi overall I want...                Gaming
# 7795   SZA's CTRL available on:\nApple Music - http:/...                 Music
# 8593   The time has come. Let the regeneration begin…...         Entertainment
# 10195  Danielle Bregoli thinks Logan Paul should be a...         Entertainment
# 10400  Yung n Rich in the mirror I see both of em👁🤑 👅...                 Music
# 11596  Donald Trump had a preposterous day which star...                Comedy
# 12412  All proceeds from this stream went to https://...                Comedy
# 13397  Ugandan Knuckles Memes reacted to by Elders! O...         Entertainment
# 15405  PREVIOUS EPISODE ► https://www.youtube.com/wat...                Comedy
# 16000  Listen to Savior --\nAmazon: https://IslandRec...                 Music
# 16190  Justin Timberlake breaks it down during the Pe...                Sports
# 18583  We are all reeling after yet another senseless...                Comedy
# 18980  Emma Gonzalez, a student at the Parkland, Flor...       News & Politics
# 26527  In a polarized world, the next installment in ...      Film & Animation
# 26536  BHAD BHABIE - Gucci Flip Flops ft. Lil Yachty ...        People & Blogs
# 30797  President Trump calls into 'Fox & Friends' to ...       News & Politics
# 33809  ► Listen LIVE: http://power1051fm.com/► Facebo...         Entertainment
# 35271  The return of a fan-favorite. The legacy of Zo...                Gaming
# 35435  After the tragic death of their mother, three ...         Entertainment
# 35921  A judge ruled in favor of parents who wanted t...       News & Politics
# 38588  The actor and long-time critic of Donald Trump...       News & Politics
#
# [476 rows x 17 columns]

# %%
#Deletando os Outliers encontrados
df_GB2 = df_GB2.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)

# %%
#Percentual dos valores nulos
percent_missing = round(df_GB2.isnull().sum() * 100 / len(df_GB2),2)
missing_value_df = pd.DataFrame({'column_name': df_GB2.columns, 'percent_missing': percent_missing})
missing_value_df = missing_value_df[missing_value_df['percent_missing'] > 0]
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)
missing_value_df
# Out:
#                  column_name  percent_missing
# description      description             1.93
# category_name  category_name             0.18

# %%
#Substituindo os valores na da coluna description e category_name por'Missing' 
df_GB2.description.fillna('Missing', inplace=True)
df_GB2.category_name.fillna('Missing', inplace=True)

# %%
# Detectando Valores nulos
df_GB2.isnull().sum()/ len(df_GB2) * 100
# Out:
# video_id                  0.0
# trending_date             0.0
# title                     0.0
# channel_title             0.0
# category_id               0.0
# publish_time              0.0
# tags                      0.0
# views                     0.0
# likes                     0.0
# dislikes                  0.0
# comment_count             0.0
# thumbnail_link            0.0
# comments_disabled         0.0
# ratings_disabled          0.0
# video_error_or_removed    0.0
# description               0.0
# category_name             0.0
# dtype: float64

# %%
# Bloxpot feature 'category_id'
plt.boxplot(df_GB2['category_id'])
plt.title('Boxplot: category_id')
plt.ylabel('category_id')
# Out:
# Text(0, 0.5, 'category_id')

# %% [markdown]
# #### Análise e Visualização

# %%
#Correlação de todas as variáveis

plt.figure(figsize=[20,10])
plt.title('Correlation between features total dataset')
sns.heatmap(df_GB2.corr(), annot=True, fmt='.2f', vmin=-1, vmax=1, cmap=sns.diverging_palette(999, 999, n=20))
plt.show()

# %% [markdown]
# ### Modelando

# %%
#Deletando as colunas "genero" e "des_email"
train_bkp = df_GB2.copy()
df_GB2.drop(['video_id', 'trending_date', 'title', 'channel_title', 'publish_time', 'tags', 'thumbnail_link', 'description', 'category_name', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed' ],axis=1,inplace=True)
df_GB2.head()
# Out:
#    category_id    views  likes  dislikes  comment_count
# 0           24  1053632  25561      2294           2757
# 1           17    27833    193        12             37
# 2           25     9815     30         2             30
# 3           24  1182775  52708      1431           2333
# 4           22  1164201  57309       749            624

# %%
x = df_GB2
y = df_GB2

# %%
#Separando o dataframe em traino e teste
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#Construção do Modelo de classificação Random Forest
from sklearn.ensemble import RandomForestClassifier
rfmodel = RandomForestClassifier(random_state=0,n_estimators=450,criterion='gini',n_jobs=-1,max_depth = 8,min_samples_leaf=1,min_samples_split= 11)

#Treinamento do modelo em X_train, Y_train
rfmodel.fit(x_train,y_train)

#Predição do modelo no X_test
y_pred = rfmodel.predict(x_test)
proba = rfmodel.predict_proba(x_test)

#Variáveis Importantes
imp = rfmodel.feature_importances_
names = df_GB2.columns

imp, names = zip(*sorted(zip(imp, names)))

plt.barh(range(len(names)), imp, align = "center")
plt.yticks(range(len(names)), names)
plt.xlabel("Importance of Features")
plt.ylabel("Features")
plt.title("Importance of each feature")
fig=plt.gcf()
fig.set_size_inches(18,5)
plt.show()

# %%
a = {'names':names,'imp':imp}
tabela = pd.DataFrame(data=a)
tabela
# Out:
#            names       imp
# 0          views  0.077390
# 1  comment_count  0.092003
# 2       dislikes  0.097492
# 3          likes  0.100149
# 4    category_id  0.632967
